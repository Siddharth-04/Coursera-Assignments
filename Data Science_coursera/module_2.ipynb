# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Siddharth Singh**
# <br>Computer Engineering Student

# %% [markdown]
# *I am interested in data science because I love telling stories with data and using data to help bring that data to life.I love helping others. In data science that could be helping a business understand its customers or improving the way it uses its customer data.*

# %% [markdown]
# ### Division in Python : When you divide in Python 3, your quotient will always be returned as a float, even if you use two integers:

# %%
80/5
# Out:
# 16.0

# %% [markdown]
# Data Science Languages

# %%
Python: A versatile language with many popular machine learning libraries, such as scikit-learn, tensorflow, and keras 
R: A statistical language that's optimized for data science tasks 
SQL: A language that's crucial for working with large datasets, as it allows users to access, update, and manipulate data stored in databases 
SAS: A statistical analysis software that's used for retrieving, reporting, and analyzing statistical data 
TensorFlow: An ML-based framework that's used to tackle large datasets 
Other programming languages used in data science include:
Julia, Java, Scala, C/C++, JavaScript, Swift, Go, and MATLAB

# %% [markdown]
# Data Science Libraries

# %%
Top 20 Python Libraries for Data Science
TensorFlow
NumPy
SciPy 
Pandas
Matplotlib 
Keras
SciKit-Learn
PyTorch
Scrapy
BeautifulSoup
LightGBM
ELI5
Theano
NuPIC
Ramp
Pipenv
Bob
PyBrain
Caffe2
Chainer

# %% [markdown]
# Data Science Tools

# %%
Python
R
SQL
Apache Spark	
TensorFlow
Jupyter Notebooks
Microsoft Excel
SAS

# %% [markdown]
# Hours to Minutes

# %%
hours = int(input("Please enter hours:"))
minutes = hours * 60
print(minutes, " Minutes")

# %% [markdown]
# Arithemtic Expressions

# %%
# Constant Expressions 
x = 15 + 1.3
  
print(x)

# %% [markdown]
# Mutlipy and Add two numbers

# %%
# Add 
x = 15 + 1.3
  
print(x)

# Multiply
y = 15 * 1.3
  
print(y)

# %% [markdown]
# Objective

# %%
Gain data science knowledge and about its tools,languages and its libraries.

# %% [markdown]
# Author's Detail

# %%
- My name is Siddharth Singh

Here is the Markdown Table ->

| Name      | Address|
|-------    |--------|
| Siddharth | Delhi  |


[Here is Hyperlink to my GitHub](https://github.com/Siddharth-04)



```python
# Code & Syntax Highlighting in Python
import antigravity
```


> This is a Blockquote


Erase your mistakes using strike-through ~~like this~~.



And, I love BatMan ![alt text](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRFxOXujDJBijf-Ekp9f4Ol09aDaz5p9t2BLA&s)
